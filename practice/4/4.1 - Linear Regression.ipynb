# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# generation of synthetic dataset
N = 100
a = 1
b = 3

x = np.random.uniform(0, 5, N)
noise = np.random.normal(0, .5, N)
y = a * x + b + noise

plt.grid()
plt.scatter(x, y, marker = '.', color = 'r')

# %%
X = x.reshape(-1, 1)

# %%
x # 1d array
# Out:
# array([3.38400375, 4.13819512, 3.5625876 , 1.4054027 , 0.56364716,
#        1.32561967, 2.99861338, 3.33982074, 3.50187216, 0.56688667,
#        0.39391645, 4.61774713, 2.7734855 , 1.2029972 , 4.59518672,
#        3.41658906, 2.77325591, 1.31172211, 2.57104438, 3.39520812,
#        2.68984138, 2.62791651, 2.35458228, 1.73916017, 3.23594069,
#        2.99903463, 0.69271218, 1.1597356 , 0.70325376, 0.35608658,
#        3.93733207, 0.47278521, 1.62054986, 4.43175183, 1.76288646,
#        3.25543752, 0.71435192, 4.72856965, 1.38727544, 3.52398806,
#        3.88801694, 2.30298601, 3.32441429, 4.98939171, 2.02050204,
#        3.5171516 , 2.21389932, 1.98547098, 0.07976327, 1.97206445,
#        2.12406324, 0.74993202, 3.26129513, 3.69023374, 4.50562627,
#        0.12769005, 0.59252126, 1.99611681, 0.75557041, 2.6598515 ,
#        0.13511892, 1.77244771, 4.89804029, 2.96129655, 2.54024633,
#        2.77603891, 3.36012498, 4.45732093, 3.18189351, 4.92858417,
#        2.84068663, 0.85899449, 4.65400917, 4.97691096, 3.69033306,
#        2.41051007, 3.74717747, 0.28220134, 2.74802997, 3.72376718,
#        1.22207905, 4.05548578, 0.6425491 , 3.68140088, 4.87081149,
#        4.53568823, 3.57987756, 3.1989474 , 3.8746269 , 1.84378969,
#        4.24955498, 4.64526825, 0.26446854, 4.48562088, 0.48512936,
#        4.13558988, 2.35057386, 1.58396263, 4.79979541, 2.97572409])

# %%
X # array where each row is an array to
# Out:
# array([[3.38400375],
#        [4.13819512],
#        [3.5625876 ],
#        [1.4054027 ],
#        [0.56364716],
#        [1.32561967],
#        [2.99861338],
#        [3.33982074],
#        [3.50187216],
#        [0.56688667],
#        [0.39391645],
#        [4.61774713],
#        [2.7734855 ],
#        [1.2029972 ],
#        [4.59518672],
#        [3.41658906],
#        [2.77325591],
#        [1.31172211],
#        [2.57104438],
#        [3.39520812],
#        [2.68984138],
#        [2.62791651],
#        [2.35458228],
#        [1.73916017],
#        [3.23594069],
#        [2.99903463],
#        [0.69271218],
#        [1.1597356 ],
#        [0.70325376],
#        [0.35608658],
#        [3.93733207],
#        [0.47278521],
#        [1.62054986],
#        [4.43175183],
#        [1.76288646],
#        [3.25543752],
#        [0.71435192],
#        [4.72856965],
#        [1.38727544],
#        [3.52398806],
#        [3.88801694],
#        [2.30298601],
#        [3.32441429],
#        [4.98939171],
#        [2.02050204],
#        [3.5171516 ],
#        [2.21389932],
#        [1.98547098],
#        [0.07976327],
#        [1.97206445],
#        [2.12406324],
#        [0.74993202],
#        [3.26129513],
#        [3.69023374],
#        [4.50562627],
#        [0.12769005],
#        [0.59252126],
#        [1.99611681],
#        [0.75557041],
#        [2.6598515 ],
#        [0.13511892],
#        [1.77244771],
#        [4.89804029],
#        [2.96129655],
#        [2.54024633],
#        [2.77603891],
#        [3.36012498],
#        [4.45732093],
#        [3.18189351],
#        [4.92858417],
#        [2.84068663],
#        [0.85899449],
#        [4.65400917],
#        [4.97691096],
#        [3.69033306],
#        [2.41051007],
#        [3.74717747],
#        [0.28220134],
#        [2.74802997],
#        [3.72376718],
#        [1.22207905],
#        [4.05548578],
#        [0.6425491 ],
#        [3.68140088],
#        [4.87081149],
#        [4.53568823],
#        [3.57987756],
#        [3.1989474 ],
#        [3.8746269 ],
#        [1.84378969],
#        [4.24955498],
#        [4.64526825],
#        [0.26446854],
#        [4.48562088],
#        [0.48512936],
#        [4.13558988],
#        [2.35057386],
#        [1.58396263],
#        [4.79979541],
#        [2.97572409]])

# %%
# a * x + b = y

model = LinearRegression()
model.fit(X, y)
model
# Out:
# LinearRegression()

# %%
a_found = model.coef_[0]
b_found = model.intercept_

# %%
a_found
# Out:
# np.float64(0.9655526121795416)

# %%
b_found
# Out:
# np.float64(3.0798980328503394)
